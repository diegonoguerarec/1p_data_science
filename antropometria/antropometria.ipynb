# %% [markdown]
# # Importacion de librerias

# %%
import pandas as pd

# %% [markdown]
# # Datos

# %%
datos = pd.read_csv("antropometria_diego.csv")
datos.head()
# Out:
#     Nutri       Fecha  Masa corporal (Kg)  Talla corporal (cm)  \
# 0  Johana  04/04/2023                82.6                  NaN
# 1  Johana  27/11/2023                86.9                  NaN
# 2  Johana  12/12/2024                84.7                  NaN
# 3  Johana  27/03/2025                87.5                  NaN
# 4  Johana  23/07/2025                85.3                  NaN
#
#    Talla sentado (cm)  Envergadura de brazos (cm)  Biacromial  \
# 0                 NaN                         NaN         NaN
# 1                 NaN                         NaN         NaN
# 2                 NaN                         NaN         NaN
# 3                 NaN                         NaN         NaN
# 4                 NaN                         NaN         NaN
#
#    Antero-posterior del tórax  Transverso del tórax  Biileocrestal  ...  \
# 0                         NaN                   NaN            NaN  ...
# ...

# %%
datos_pliegues = datos[["Nutri", "Fecha", "Masa corporal (Kg)", "Tríceps", "Subescapular", "Bíceps", "Cresta ilíaca", "Supraespinal", "Abdominal", "Muslo", "Pierna.1", "Sumatoria de pliegues"]]
datos_pliegues.head()
# Out:
#     Nutri       Fecha  Masa corporal (Kg)  Tríceps  Subescapular  Bíceps  \
# 0  Johana  04/04/2023                82.6      9.0           9.2     3.2
# 1  Johana  27/11/2023                86.9      8.2          10.4     3.4
# 2  Johana  12/12/2024                84.7      5.8           8.8     3.2
# 3  Johana  27/03/2025                87.5      5.6           9.2     3.4
# 4  Johana  23/07/2025                85.3      7.8          10.0     3.2
#
#    Cresta ilíaca  Supraespinal  Abdominal  Muslo  Pierna.1  \
# 0            8.6           5.4        7.4   11.8       5.8
# 1           11.6           7.2       10.0   12.4       5.8
# 2            6.0           4.4        6.2    8.2       4.6
# 3            8.8           5.2        7.6    8.4       4.4
# 4            9.0           5.4        8.8    9.0       4.4
#
#    Sumatoria de pliegues
# 0                   48.6
# 1                   54.0
# 2                   38.0
# 3                   40.4
# 4                   45.4

# %%
datos_pliegues.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Nutri                  16 non-null     object
#  1   Fecha                  16 non-null     object
#  2   Masa corporal (Kg)     16 non-null     float64
#  3   Tríceps                16 non-null     float64
#  4   Subescapular           16 non-null     float64
#  5   Bíceps                 16 non-null     float64
#  6   Cresta ilíaca          16 non-null     float64
#  7   Supraespinal           16 non-null     float64
#  8   Abdominal              16 non-null     float64
#  9   Muslo                  16 non-null     float64
#  10  Pierna.1               16 non-null     float64
#  11  Sumatoria de pliegues  16 non-null     float64
# dtypes: float64(10), object(2)
# memory usage: 1.6+ KB

# %%
# Convertir la columna Fecha a datetime
datos_pliegues["Fecha"] = pd.to_datetime(datos_pliegues["Fecha"], format="%d/%m/%Y")
# Out:
# /tmp/ipykernel_7441/777743819.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_pliegues["Fecha"] = pd.to_datetime(datos_pliegues["Fecha"], format="%d/%m/%Y")

# %%
datos_pliegues.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Nutri                  16 non-null     object
#  1   Fecha                  16 non-null     datetime64[ns]
#  2   Masa corporal (Kg)     16 non-null     float64
#  3   Tríceps                16 non-null     float64
#  4   Subescapular           16 non-null     float64
#  5   Bíceps                 16 non-null     float64
#  6   Cresta ilíaca          16 non-null     float64
#  7   Supraespinal           16 non-null     float64
#  8   Abdominal              16 non-null     float64
#  9   Muslo                  16 non-null     float64
#  10  Pierna.1               16 non-null     float64
#  11  Sumatoria de pliegues  16 non-null     float64
# dtypes: datetime64[ns](1), float64(10), object(1)
# memory usage: 1.6+ KB

# %%
datos_pliegues
# Out:
#       Nutri      Fecha  Masa corporal (Kg)  Tríceps  Subescapular  Bíceps  \
# 0    Johana 2023-04-04                82.6      9.0           9.2     3.2
# 1    Johana 2023-11-27                86.9      8.2          10.4     3.4
# 2    Johana 2024-12-12                84.7      5.8           8.8     3.2
# 3    Johana 2025-03-27                87.5      5.6           9.2     3.4
# 4    Johana 2025-07-23                85.3      7.8          10.0     3.2
# 5    Johana 2025-09-17                80.9      7.6          10.2     3.4
# 6   Deborah 2022-02-03                84.3     12.4          10.8     4.4
# 7   Deborah 2022-04-01                82.4      8.6          10.8     3.4
# 8   Deborah 2022-05-20                82.4      8.8          10.8     3.4
# 9   Deborah 2020-02-25                77.3     12.0           9.4     3.8
# 10   Johana 2020-10-20                77.5      8.6           9.4     3.6
# 11   Johana 2020-11-24                80.5      7.0           8.0     2.0
# ...

# %%
# Ordenar por fecha
datos_pliegues = datos_pliegues.sort_values(by="Fecha")

# %%
datos_pliegues
# Out:
#       Nutri      Fecha  Masa corporal (Kg)  Tríceps  Subescapular  Bíceps  \
# 9   Deborah 2020-02-25                77.3     12.0           9.4     3.8
# 10   Johana 2020-10-20                77.5      8.6           9.4     3.6
# 11   Johana 2020-11-24                80.5      7.0           8.0     2.0
# 12  Deborah 2021-02-24                82.7     10.4          10.2     5.2
# 13  Deborah 2021-06-18                83.5     10.0           9.0     3.0
# 6   Deborah 2022-02-03                84.3     12.4          10.8     4.4
# 7   Deborah 2022-04-01                82.4      8.6          10.8     3.4
# 8   Deborah 2022-05-20                82.4      8.8          10.8     3.4
# 15  Deborah 2023-01-09                84.4      9.2          10.3     3.6
# 0    Johana 2023-04-04                82.6      9.0           9.2     3.2
# 1    Johana 2023-11-27                86.9      8.2          10.4     3.4
# 14    Kevin 2024-01-31                88.9      8.8           8.2     3.2
# ...
